# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Shunom/ML-MODEL-FOR-ADRB1-IC50-Predection/blob/main/CDD_ML_1_Bioactivity_Data_Concised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 925.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Beta-1 adrenergic receptors**

# %%
# Target search for beta-1 adrenergic receptors
target = new_client.target
target_query = target.search('ADRB1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'B0FL73', 'xref_name': None, 'xre...    Cavia porcellus
# 1   [{'xref_id': 'P08588', 'xref_name': None, 'xre...       Homo sapiens
# 2                                                  []       Mus musculus
# 3   [{'xref_id': 'P18090', 'xref_name': None, 'xre...  Rattus norvegicus
# 4   [{'xref_id': 'Q28998', 'xref_name': None, 'xre...         Sus scrofa
# 5                                                  []       Homo sapiens
# 6                                                  []       Homo sapiens
# 7                                                  []       Homo sapiens
# 8                                                  []  Rattus norvegicus
# 9                                                  []       Mus musculus
# 10                                                 []       Homo sapiens
#
#                                   pref_name  score  species_group_flag  \
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL213'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1536                                               None             None
# 1537                                               None             None
# 1538                                               None             None
# 1539                                               None             None
# 1540  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('ADRB1_Inhibitory_raw.csv', index=False)

# %% [markdown]
# ## **Copying files to google drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Create a data folder in google drive**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp ADRB1_Inhibitory_raw.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 784
# -rw------- 1 root root 746496 Aug  2 23:19 ADRB1_Inhibitory_raw.csv
# -rw------- 1 root root  55579 Aug  2 23:02 bioactivity_preprocessed_data.csv

# %% [markdown]
# # A glimpse of the file **contents**

# %%
! ls
# Out:
# ADRB1_Inhibitory_raw.csv  bioactivity_preprocessed_data.csv  gdrive  sample_data

# %%
! head ADRB1_Inhibitory_raw.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-102-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1536                                               None             None
# 1537                                               None             None
# 1538                                               None             None
# 1539                                               None             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 662

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1535                                               None             None
# 1536                                               None             None
# 1537                                               None             None
# 1538                                               None             None
# 1540  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# **Labeling active, inactive, and intermediate**

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# # **Selecting parameters**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL305153         CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21
# 1          CHEMBL368457             CC(C)(C)NCC(O)CON=C1c2ccccc2-c2ccccc21
# 2         CHEMBL1788270        CC(C)(C)NC[C@@H](O)CON=C1c2ccccc2-c2ccccc21
# 3          CHEMBL266195                          C=CCc1ccccc1OCC(O)CNC(C)C
# 4             CHEMBL423                   CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1
# ...                 ...                                                ...
# 1536      CHEMBL4514723  CC(C)NC[C@H](O)COc1ccccc1CCCn1cc(CNCc2cn(CCCc3...
# 1537      CHEMBL3582478           CC(C)(O)c1cncc(-c2nc3ccc(F)cc3n2C2CC2)c1
# 1538      CHEMBL5092058  Cc1cn([C@H](C)CC#N)c(=O)c2cc(Cn3nc(C(F)F)cc3Cl...
# 1539      CHEMBL3582478           CC(C)(O)c1cncc(-c2nc3ccc(F)cc3n2C2CC2)c1
# 1540      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#      standard_value
# 0              29.4
# 1              37.9
# ...

# %%
data_tuples = list(zip(df3.molecule_chembl_id, df3.canonical_smiles, bioactivity_class, df3.standard_value))
df3 = pd.DataFrame(data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class','standard_value'])
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL305153         CC(C)(C)NC[C@H](O)CON=C1c2ccccc2-c2ccccc21
# 1         CHEMBL368457             CC(C)(C)NCC(O)CON=C1c2ccccc2-c2ccccc21
# 2        CHEMBL1788270        CC(C)(C)NC[C@@H](O)CON=C1c2ccccc2-c2ccccc21
# 3         CHEMBL266195                          C=CCc1ccccc1OCC(O)CNC(C)C
# 4            CHEMBL423                   CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1
# ..                 ...                                                ...
# 689      CHEMBL4514723  CC(C)NC[C@H](O)COc1ccccc1CCCn1cc(CNCc2cn(CCCc3...
# 690      CHEMBL3582478           CC(C)(O)c1cncc(-c2nc3ccc(F)cc3n2C2CC2)c1
# 691      CHEMBL5092058  Cc1cn([C@H](C)CC#N)c(=O)c2cc(Cn3nc(C(F)F)cc3Cl...
# 692      CHEMBL3582478           CC(C)(O)c1cncc(-c2nc3ccc(F)cc3n2C2CC2)c1
# 693      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#     bioactivity_class standard_value
# 0              active           29.4
# ...

# %% [markdown]
# # **Save the pre-processed data**

# %% [markdown]
# converts to csv

# %%
df3.to_csv('Bioactivity_ADRB1_Inhibitory_preprocessed.csv', index=False)

# %%
! ls -1
# Out:
# ADRB1_Inhibitory_raw.csv
# Bioactivity_ADRB1_Inhibitory_preprocessed.csv
# bioactivity_preprocessed_data.csv
# gdrive
# sample_data

# %% [markdown]
# Saves to google drive

# %%
! cp Bioactivity_ADRB1_Inhibitory_preprocessed.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# ADRB1_Inhibitory_raw.csv  Bioactivity_ADRB1_Inhibitory_preprocessed.csv
